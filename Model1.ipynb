# %%
#Import libraries
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
#mount download from drive?
from google.colab import drive
drive.mount('/content/drive/')

from pathlib import Path
import pathlib
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
# Out:
# Mounted at /content/drive/

# %%
#Bathrooms
data_dir = Path('/content/drive/My Drive/A/Bathrooms')

image_count_bathrooms = len(list(data_dir.glob('*.jpg'))) + len(list(data_dir.glob('*.jpeg')))
print(image_count_bathrooms)

import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import random

bathrooms_jpeg = list(data_dir.glob('*.jpeg'))
print(len(bathrooms_jpeg))

bathrooms_jpg = list(data_dir.glob('*.jpg'))
print(len(bathrooms_jpg))

bathrooms = bathrooms_jpeg + bathrooms_jpeg 
print(len(bathrooms)) #why is this value greater than image_count?


randimgbr = random.randint(1, len(bathrooms))

PIL.Image.open(str(bathrooms[randimgbr]))

# PIL.Image.open(str(bathrooms[34]))
# Out:
# 400
# 215
# 185
# 430
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x100 at 0x7F770F9A2160>

# %%
#Bedrooms
data_dir = Path('/content/drive/My Drive/A/Bedrooms')

image_count_bedrooms = len(list(data_dir.glob('*.jpg'))) + len(list(data_dir.glob('*.jpeg')))
print(image_count_bedrooms)

import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import random

bedrooms_jpeg = list(data_dir.glob('*.jpeg'))
print(len(bedrooms_jpeg))

bedrooms_jpg = list(data_dir.glob('*.jpg'))
print(len(bedrooms_jpg))

bedrooms = bedrooms_jpeg + bedrooms_jpeg 
print(len(bedrooms)) #value less than image_count?


randimgbd = random.randint(1, len(bedrooms))
PIL.Image.open(str(bedrooms[randimgbd]))


# PIL.Image.open(str(bedrooms[78]))
# Out:
# 425
# 174
# 251
# 348
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=283x178 at 0x7F76D5607710>

# %%
#Kitchens
data_dir = Path('/content/drive/My Drive/A/Kitchens')

image_count_kitchens = len(list(data_dir.glob('*.jpg'))) + len(list(data_dir.glob('*.jpeg')))
print(image_count_kitchens)

import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import random

kitchens_jpeg = list(data_dir.glob('*.jpeg'))
print(len(kitchens_jpeg))

kitchens_jpg = list(data_dir.glob('*.jpg'))
print(len(kitchens_jpg))

kitchens = kitchens_jpeg + kitchens_jpeg 
print(len(kitchens)) #value is equal to image_count?

randimgk = random.randint(1, len(kitchens))
PIL.Image.open(str(kitchens[randimgk]))

# PIL.Image.open(str(kitchens[24]))
# Out:
# 282
# 159
# 123
# 318
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x100 at 0x7F76D5556DD8>

# %%
#Living rooms
data_dir = Path('/content/drive/My Drive/A/Living')

image_count_living = len(list(data_dir.glob('*.jpg'))) + len(list(data_dir.glob('*.jpeg')))
print(image_count_living)

import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import random

living_jpeg = list(data_dir.glob('*.jpeg'))
print(len(living_jpeg))

living_jpg = list(data_dir.glob('*.jpg'))
print(len(living_jpg))

living = living_jpeg + living_jpeg 
print(len(living)) #value less than image_count?

randimglv = random.randint(1, len(living))
PIL.Image.open(str(living[randimglv]))

# PIL.Image.open(str(living[78]))
# Out:
# 305
# 154
# 151
# 308
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x100 at 0x7F76D5585F60>

# %%
#Exterior

data_dir = Path('/content/drive/My Drive/A/Exterior')

image_count_exterior = len(list(data_dir.glob('*.jpg'))) + len(list(data_dir.glob('*.jpeg'))) + len(list(data_dir.glob('*.jfif')))
print(image_count_exterior)

import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import random

exterior_jpeg = list(data_dir.glob('*.jpeg'))
print(len(exterior_jpeg))

exterior_jpg = list(data_dir.glob('*.jpg'))
print(len(exterior_jpg))

exterior_jfif = list(data_dir.glob('*.jfif'))
print(len(exterior_jfif))

exterior = exterior_jpeg + exterior_jpg + exterior_jfif
print(len(exterior))

randimgext = random.randint(1, len(exterior))
PIL.Image.open(str(exterior[randimgext]))
# Out:
# 339
# 5
# 77
# 257
# 339
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x7F76D3D17908>

# %%
data_dir = Path('/content/drive/My Drive/A/Backyards')

image_count_backyards = len(list(data_dir.glob('*.jpg'))) + len(list(data_dir.glob('*.jpeg'))) + len(list(data_dir.glob('*.jfif')))
print(image_count_backyards)

import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import random

backyards_jpeg = list(data_dir.glob('*.jpeg'))
print(len(backyards_jpeg))

backyards_jpg = list(data_dir.glob('*.jpg'))
print(len(backyards_jpg))

backyards_jfif = list(data_dir.glob('*.jfif'))
print(len(backyards_jfif))

backyards = backyards_jpeg + backyards_jpg + backyards_jfif
print(len(backyards))

randimgext = random.randint(1, len(backyards))
PIL.Image.open(str(backyards[randimgext]))
# Out:
# 283
# 9
# 76
# 198
# 283
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x7F76D3D339B0>

# %%
#identify path + cwd contents
from pathlib import Path

print(f"Current directory: {Path.cwd()}")
print(f"Home directory: {Path.home()}")

from pathlib import Path

path = Path('/content')

dirs = [e for e in path.iterdir() if e.is_dir()]
print(dirs)
# Out:
# Current directory: /content
# Home directory: /root
# [PosixPath('/content/.config'), PosixPath('/content/drive'), PosixPath('/content/sample_data')]

# %%
#validation split in dataset
batch_size = 32
img_height = 180
img_width = 180

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

train_ds = keras.preprocessing.image_dataset_from_directory(
  "/content/drive/My Drive/A",
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)

print(class_names) #what do I do about the extra classes nAnI?!?!?!  ;-;
# Out:
# Found 1656 files belonging to 7 classes.
# Using 1325 files for training.
# ['Backyards', 'Bathrooms', 'Bedrooms', 'Exterior', 'Kitchens', 'Living', 'Test Houses']
# ['Backyards', 'Bathrooms', 'Bedrooms', 'Exterior', 'Kitchens', 'Living', 'Test Houses']

# %%
#validation split in dataset
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

val_ds = keras.preprocessing.image_dataset_from_directory(
  '/content/drive/My Drive/A',
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1656 files belonging to 7 classes.
# Using 331 files for validation.

# %%
import matplotlib.pyplot as plt

class_names = train_ds.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break

AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixels values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# (32, 180, 180, 3)
# (32,)
# 0.0 1.0

# %%
#data augmentation
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %%
#data augmentation print
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
#the model 
num_classes = 6 #affects the epoch because there are five class labels. need to fix extra label 

#with data augmentation and dropout
model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# sequential (Sequential)      (None, 180, 180, 3)       0
# _________________________________________________________________
# rescaling_1 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 64)        18496
# ...

# %%
#train the model
epochs=11
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/11
#  3/42 [=>............................] - ETA: 38s - loss: 2.0733 - accuracy: 0.1927
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-17-7096d3f131de> in <module>()
#       4   train_ds,
#       5   validation_data=val_ds,
# ----> 6   epochs=epochs
#       7 )
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss=history.history['loss']
val_loss=history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
test_url = "https://www.deltafaucet.com/sites/delta/files/2019-12/bathtub-classic-400-featured_0.jpg"
test_path = tf.keras.utils.get_file('test_image25', origin=test_url)

img = keras.preprocessing.image.load_img(
    test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)

# %%
#Dropout
model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# sequential_2 (Sequential)    (None, 180, 180, 3)       0
# _________________________________________________________________
# rescaling_2 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 45, 45, 64)        18496
# ...

# %%
epochs = 15
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/15
# 41/41 [==============================] - 1s 30ms/step - loss: 1.6833 - accuracy: 0.2683 - val_loss: 1.4712 - val_accuracy: 0.3262
# Epoch 2/15
# 41/41 [==============================] - 1s 26ms/step - loss: 1.4532 - accuracy: 0.3613 - val_loss: 1.5763 - val_accuracy: 0.3169
# Epoch 3/15
# 41/41 [==============================] - 1s 26ms/step - loss: 1.3765 - accuracy: 0.3920 - val_loss: 2.4914 - val_accuracy: 0.2092
# Epoch 4/15
# 41/41 [==============================] - 1s 26ms/step - loss: 1.3366 - accuracy: 0.4404 - val_loss: 1.3587 - val_accuracy: 0.3877
# Epoch 5/15
# 41/41 [==============================] - 1s 26ms/step - loss: 1.2302 - accuracy: 0.4958 - val_loss: 1.2172 - val_accuracy: 0.5231
# Epoch 6/15
# 41/41 [==============================] - 1s 26ms/step - loss: 1.1408 - accuracy: 0.5596 - val_loss: 1.2389 - val_accuracy: 0.4954
# Epoch 7/15
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#looping through options for batch size, epochs, dropout
for batch_size in [8, 16, 32, 64, 128]:
  for epochs in [10, 20, 30, 40]:
    for dropout_pc in [0.1, 0.2, 0.3]:
      num_classes = 5 
      #validation split in dataset
      batch_size = batch_size
      img_height = 180
      img_width = 180

      from tensorflow import keras
      from tensorflow.keras import layers
      from tensorflow.keras.models import Sequential

      train_ds = keras.preprocessing.image_dataset_from_directory(
        "/content/drive/My Drive/A",
        validation_split=0.2,
        subset="training",
        seed=123,
        image_size=(img_height, img_width),
        batch_size=batch_size)

      class_names = train_ds.class_names

      #validation split in dataset

      val_ds = keras.preprocessing.image_dataset_from_directory(
        '/content/drive/My Drive/A',
        validation_split=0.2,
        subset="validation",
        seed=123,
        image_size=(img_height, img_width),
        batch_size=batch_size)


      #with data augmentation ??
      model = Sequential([
        data_augmentation,
        layers.experimental.preprocessing.Rescaling(1./255),
        layers.Conv2D(16, 3, padding='same', activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(32, 3, padding='same', activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, padding='same', activation='relu'),
        layers.MaxPooling2D(),
        layers.Dropout(dropout_pc),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dense(num_classes)
      ])


      model.compile(optimizer='adam',
                    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                    metrics=['accuracy'])

      model.summary()
      epochs = epochs
      history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs
      )

      acc = history.history['accuracy']
      val_acc = history.history['val_accuracy']

      loss = history.history['loss']
      val_loss = history.history['val_loss']

      epochs_range = range(epochs)

      plt.figure(figsize=(8, 8))
      plt.subplot(1, 2, 1)
      plt.plot(epochs_range, acc, label='Training Accuracy')
      plt.plot(epochs_range, val_acc, label='Validation Accuracy')
      plt.legend(loc='lower right')
      plt.title('Training and Validation Accuracy')

      plt.subplot(1, 2, 2)
      plt.plot(epochs_range, loss, label='Training Loss')
      plt.plot(epochs_range, val_loss, label='Validation Loss')
      plt.legend(loc='upper right')
      plt.title('Training and Validation Loss')
      plt.show()


      print("Batch size: " + str(batch_size) + ", epochs: " + str(epochs) + ", dropout: " + str(dropout_pc))
      #print("validation: " + str(validation_acc))
